# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaqgopang/image_prompt/blob/main/image_as_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai

# %%
genai.configure(api_key= GEMINI_API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import requests
from PIL import Image
from io import BytesIO
from IPython.display import display
import time

url = "https://images.unsplash.com/photo-1732951340728-d8b726561d50?w=500&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxmZWF0dXJlZC1waG90b3MtZmVlZHwxNjZ8fHxlbnwwfHx8fHw%3D"

response = requests.get(url)

img = Image.open(BytesIO(response.content))
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x750>

# %%
prompt = '''
discribe the image in detail
'''

response = model.generate_content([prompt , img])

response = model.generate_content([prompt , img])
time.sleep(1)
print(response.text)
# Out:
# Here's a description of the image:
#
# The photograph is a landscape-oriented shot taken at twilight or dawn.
#
#
# The main focus is on two hot air balloons, positioned slightly off-center, that are illuminated from within, creating a warm glow against the darkening sky.  The balloons appear to be close together, almost touching, and their shapes are somewhat distorted, perhaps by the angle of the shot or the way the air is moving. One balloon is slightly larger and brighter than the other.
#
# The balloons are situated in a valley or canyon-like landscape with characteristic rock formations. These formations are dark, muted tones of grey and brown, with soft, undulating surfaces. The texture of the rock is rough and uneven. Some small patches of yellow-green vegetation are visible around the balloons, suggesting sparse, low-lying plants.
#
# ...
